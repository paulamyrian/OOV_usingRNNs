# %%
#tratamento dos dados

# %%
import pandas as pd

# %%
df = pd.read_csv('tourism_amazon.csv', encoding='utf-8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         1018 non-null   object
#  1   status_message    1018 non-null   object
#  2   link_name         555 non-null    object
#  3   status_type       1018 non-null   object
#  4   status_link       1006 non-null   object
#  5   status_published  1018 non-null   object
#  6   num_reactions     1018 non-null   float64
#  7   num_comments      1018 non-null   float64
#  8   num_shares        1018 non-null   float64
#  9   num_likes         1018 non-null   float64
#  10  num_loves         1018 non-null   float64
#  11  num_wows          1018 non-null   float64
#  12  num_hahas         1018 non-null   float64
#  13  num_sads          1018 non-null   float64
#  14  num_angrys        1018 non-null   float64
#  15  num_special       1018 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['status_id', 'status_message', 'link_name', 'status_type',
#        'status_link', 'status_published', 'num_reactions', 'num_comments',
#        'num_shares', 'num_likes', 'num_loves', 'num_wows', 'num_hahas',
#        'num_sads', 'num_angrys', 'num_special', 'category'],
#       dtype='object')

# %%
df
# Out:
#                               status_id  \
# 0     1549061578692287_2021387448126362
# 1     1549033165419320_2139793586343272
# 2     1549061578692287_2042133349385105
# 3       380000952157262_965919786898706
# 4     1491715331132829_1777940962510263
# ...                                 ...
# 1013   216753025121174_1531868880276242
# 1014   365838463497691_1709821622432695
# 1015   156461724431781_1643086925769246
# 1016    350885085102744_798507237007191
# 1017    350885085102744_778923848965530
#
#                                          status_message  \
# 0                               Vamos tomar chopp hoje😍
# 1     Todo mundo curte um hot roll. E quem negar, me...
# 2                             Mesa cheia é mesa alegre!
# 3     Nosso Filé com Molho de Vinho é fabuloso! Ele ...
# 4                Daqui a pouco tem Malino’s Hein!\n🍔🍺🍟😍
# ...                                                 ...
# 1013                                  Queijo coalho.😋😋😋
# ...

# %%
df['status_message'].value_counts()
# Out:
# Rodízio de sushi e pratos quentes, por apenas R$ 39,90 e ganhe um Temaki Mix (Salmão e Kani).\nPromoção válida para a unidade de Santarém e enquanto durar o estoque;\nPedimos a gentileza de evitar o desperdício: Desperdício de Temaki, será cobrado o preço de um Temaki do cardápio;\nO Temaki deverá ser consumindo no estabelecimento durante o rodízio;\nO rodízio será serviço das 19 às 22:30 horas.                                                  5
# Hoje tem pão delícia, o nosso pãozinho de batata fofinho com muito queijo cuia e o melhor hoje ele é em DOBROOO! Isso mesmo em dobro, compra um e ganha o outro! Vem ser feliz na Lou Doces.\n__\n📆Seg. a Sáb. das 16h às 20:30h\n📞 (93) 99163 9870 - 99121 4996\n📍Tv. Assis de Vasconcelos, 743 (entre Mendonça Furtado e Presidente Vargas)\n\n#loudoces #delícia #gostosuras #morango #cafe #delicatessen #sonhodevalsa#paodebatata #queijocuia #loudoces    5
# ...

# %%
df.drop(['status_id', 'link_name', 'status_type','status_link', 'status_published', 'num_reactions', 'num_comments',
       'num_shares', 'num_likes', 'num_loves', 'num_wows', 'num_hahas',
       'num_sads', 'num_angrys', 'num_special', 'category'], axis=1, inplace=True)

# %%
df
# Out:
#                                          status_message
# 0                               Vamos tomar chopp hoje😍
# 1     Todo mundo curte um hot roll. E quem negar, me...
# 2                             Mesa cheia é mesa alegre!
# 3     Nosso Filé com Molho de Vinho é fabuloso! Ele ...
# 4                Daqui a pouco tem Malino’s Hein!\n🍔🍺🍟😍
# ...                                                 ...
# 1013                                  Queijo coalho.😋😋😋
# 1014  "Sábado de Sol, tem espetos de montão.." 😉\n\n...
# 1015  Segunda é dia do melhor Rodízio de Santarém!! ...
# 1016  Hoje tem pão delícia, o nosso pãozinho de bata...
# 1017  Ouuu se preferir, pode ser também um chocolate...
#
# [1018 rows x 1 columns]

# %%
#putput processed data as csv finle
df.to_csv('cleandata.csv',index=False)
